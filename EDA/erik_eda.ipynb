# %% [markdown]
# # EDA of selected file with "Överensstämelse" data from SCB
#
# I manually selected data from SCB and renamed the column categories in excel for simplicity

# %%
import pandas as pd

df = pd.read_excel('../files/överensstämmelse-2024.xlsx')

df
# Out:
#                                         Kategori  hel  viss_del  inte_alls
# 0                                         Totalt   62        25         13
# 1                                        Data/It   62        22         16
# 2        Ekonomi, administration och försäljning   69        23          9
# 3                       Friskvård och kroppsvård   60        18         22
# 4                  Hotell, restaurang och turism   45        34         21
# 5        Hälso- och sjukvård samt socialt arbete   61        29         10
# 6                   Journalistik och information   53        35         13
# 7                                        Juridik   54        39          7
# 8                       Kultur, media och design   59        19         22
# 9   Lantbruk, djurvård, trädgård, skog och fiske   68        24          8
# 10                    Pedagogik och undervisning   50        25         24
# 11                Samhällsbyggnad och byggteknik   55        26         18
# 12                             Säkerhetstjänster   74        16         10
# 13                       Teknik och tillverkning   63        26         12
# 14                             Transporttjänster   88        11          1
# 15                                        Övrigt   70        10         20

# %%
df.dtypes
# Out:
# Kategori     object
# hel           int64
# viss_del      int64
# inte_alls     int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Kategori   16 non-null     object
#  1   hel        16 non-null     int64
#  2   viss_del   16 non-null     int64
#  3   inte_alls  16 non-null     int64
# dtypes: int64(3), object(1)
# memory usage: 644.0+ bytes

# %%
df_total = df.iloc[0]

df_total
# Out:
# Kategori     Totalt
# hel              62
# viss_del         25
# inte_alls        13
# Name: 0, dtype: object

# %%
import matplotlib.pyplot as plt

def överenstämmelse():

    df = pd.read_excel('../files/överensstämmelse-2024.xlsx')

    df_total = df.iloc[0]

    values = df_total[["hel", "viss_del", "inte_alls"]].values
    labels = ["Helt och hållet", "Till viss del", "Inte alls"]

    # Tightly spaced y-positions (closer together than default [0,1,2])
    y_positions = [0, 0.5, 1.0]  # closer spacing

    fig, ax = plt.subplots(figsize=(8, 4))

    ax.barh(
        y=y_positions,
        width=values,
        color=["#3D9AC5", "grey", "lightblue"],
        height=0.2,  # keep bar thickness
    )

    # Set tick labels at custom positions
    ax.set_yticks(y_positions)
    ax.set_yticklabels(labels)

    # Invert to keep top-down order
    ax.invert_yaxis()

    # Left-aligned multiline title
    ax.text(
        x=-0.15, y=1.10,
        s="Antal (%) vars arbete överensstämmer med studier på Yrkeshögskola",
        transform=ax.transAxes,
        ha="left",
        fontsize=12,
    )

    ax.text(
    x=-0.15, y=1.03,
    s="[ett år efter examen]",
    transform=ax.transAxes,
    ha="left",
    fontsize=10,
)

    ax.set_xlabel("[%]", fontsize=12)
    ax.xaxis.set_label_coords(0.4, -0.1)

    ax.spines["top"].set_visible(False)
    ax.spines["right"].set_visible(False)

    ax.tick_params(axis="x", length=0)
    ax.tick_params(axis="y", length=0)

    ax.annotate(
    "Inte riktigt vad VD´n sa",
    xy=(values[0], y_positions[0]),
    xytext=(values[0] + 5, y_positions[0] + 0.03),
    arrowprops=dict(arrowstyle="->", color="black"),
    fontsize=10,
    ha="left"
)
    
    return fig, ax

fig, ax = överenstämmelse()
fig.tight_layout()

# %% [markdown]
# Importing similar data with gender

# %%
import pandas as pd

df_gender = pd.read_excel('../files/cleaned_gender_data.xlsx')

df_gender
# Out:
#      gender                                      category  helt  viss_del  \
# 0   Kvinnor                                        Totalt    62        25
# 1   Kvinnor                                       Data/It    65        20
# 2   Kvinnor       Ekonomi, administration och försäljning    70        22
# 3   Kvinnor                 Hotell, restaurang och turism    43        35
# 4   Kvinnor       Hälso- och sjukvård samt socialt arbete    60        29
# 5   Kvinnor                      Kultur, media och design    57        20
# 6   Kvinnor  Lantbruk, djurvård, trädgård, skog och fiske    64        28
# 7   Kvinnor                    Pedagogik och undervisning    43        30
# 8   Kvinnor                Samhällsbyggnad och byggteknik    58        25
# 9   Kvinnor                             Säkerhetstjänster    76        11
# 10  Kvinnor                       Teknik och tillverkning    62        24
# 11  Kvinnor                             Transporttjänster    80        18
# 12      Män                                        Totalt    62        24
# 13      Män                                       Data/It    61        23
# 14      Män       Ekonomi, administration och försäljning    66        24
# 15      Män                 Hotell, restaurang och turism    54        27
# 16      Män       Hälso- och sjukvård samt socialt arbete    68        24
# 17      Män                      Kultur, media och design    63        16
# 18      Män  Lantbruk, djurvård, trädgård, skog och fiske    76        17
# 19      Män                    Pedagogik och undervisning    63        16
# 20      Män                Samhällsbyggnad och byggteknik    54        27
# 21      Män                             Säkerhetstjänster    71        21
# 22      Män                       Teknik och tillverkning    63        26
# 23      Män                             Transporttjänster    91         7
#
#     inte_alls
# 0          12
# 1          15
# 2           8
# 3          21
# 4          10
# 5          23
# 6           9
# 7          26
# 8          17
# 9          13
# 10         13
# 11          2
# 12         14
# 13         16
# 14         10
# 15         19
# 16          8
# 17         20
# 18          7
# 19         22
# 20         19
# 21          7
# 22         11
# 23          2

# %%
import duckdb

df_gender2 = duckdb.query(
    """--sql
    SELECT gender, category, inte_alls
    FROM df_gender
    QUALIFY ROW_NUMBER() OVER (PARTITION BY gender ORDER BY inte_alls DESC) <= 3
    """
).to_df()

df_gender2
# Out:
#     gender                       category  inte_alls
# 0      Män     Pedagogik och undervisning         22
# 1      Män       Kultur, media och design         20
# 2      Män  Hotell, restaurang och turism         19
# 3  Kvinnor     Pedagogik och undervisning         26
# 4  Kvinnor       Kultur, media och design         23
# 5  Kvinnor  Hotell, restaurang och turism         21

# %% [markdown]
# Creating graph for top three categories "inte alls"

# %%
def gender():

    df_gender = pd.read_excel('../files/cleaned_gender_data.xlsx')

    df_gender2 = duckdb.query(
    """--sql
    SELECT gender, category, inte_alls
    FROM df_gender
    QUALIFY ROW_NUMBER() OVER (PARTITION BY gender ORDER BY inte_alls DESC) <= 3
    """
    ).to_df()

    df_gender2


    df_pivot = df_gender2.pivot(index="category", columns="gender", values="inte_alls").fillna(0)

    # Plot grouped bar chart
    fig, ax = plt.subplots(figsize=(8, 4))

    bar_width = 0.35
    y_positions = range(len(df_pivot))

    ax.text(
        x=-0.35, y=1.10,
        s="Könsskillnader där man inte alls arbetar med det man studerat 1 år efter examen",
        transform=ax.transAxes,
        ha="left",
        fontsize=12,
    )

    ax.text(
        x=-0.35, y=1.03,
        s="[Sorterat för studieområden med lägst överensstämmelse, 2024]",
        transform=ax.transAxes,
        ha="left",
        fontsize=10,  # slightly smaller
    )

    fig.subplots_adjust(top=1.5) 

    # Plot for each gender
    ax.barh(
        [y - bar_width/2 for y in y_positions],
        df_pivot["Kvinnor"],
        height=bar_width,
        label="Kvinnor",
        color="#3D9AC5"
    )
    ax.barh(
        [y + bar_width/2 for y in y_positions],
        df_pivot["Män"],
        height=bar_width,
        label="Män",
        color="grey"
    )

    # Set labels and ticks
    ax.set_yticks(y_positions)
    ax.set_yticklabels(df_pivot.index)
    ax.invert_yaxis()  # Top to bottom

    # Add x-axis label
    ax.set_xlabel("[%]", fontsize=12)
    ax.xaxis.set_label_coords(0.4, -0.1)

    # Style adjustments
    ax.spines["top"].set_visible(False)
    ax.spines["right"].set_visible(False)
    ax.tick_params(axis="x", length=0)
    ax.tick_params(axis="y", length=0)
    ax.legend()

    return fig, ax


fig, ax = gender()
fig.tight_layout()
